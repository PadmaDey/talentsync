# %%
import pandas as pd

# %%
df_jobs = pd.read_csv("../production_data/raw_data_dump/jobs.csv")
df_jobs.head(2)
# Out:
#                         _id                   title         job_id  \
# 0  6819085351179958a6041971        AI Sales Manager  JOB-AS-250505
# 1  68190c5c51179958a6041977  Human Resource Manager  JOB-HR-250505
#
#                                                 tags  status  \
# 0                                  ['Sales', 'Saas']  closed
# 1  ['Hr', 'Ai', 'Saas', 'Technology', 'Recruitment']  closed
#
#                 created_at               updated_at  is_deleted  \
# 0  2025-05-05 18:49:48.696  2025-06-12 15:43:48.710       False
# 1  2025-05-05 19:06:56.908  2025-06-12 09:23:57.898       False
#
#                  company_id location  ... non_technical_skills  \
# 0  681c861b1cf44d32fe03095e  Vietnam  ...                   []
# 1  681c861b1cf44d32fe03095e  Vietnam  ...                   []
#
#   technical_skills selection_criteria.resume_shortlist_criteria  \
# 0               []                                         60.0
# ...

# %%
df_jobs.columns
# Out:
# Index(['_id', 'title', 'job_id', 'tags', 'status', 'created_at', 'updated_at',
#        'is_deleted', 'company_id', 'location', 'address', 'job_post_name',
#        'role_description', 'experience', 'responsibilities', 'requirements',
#        'must_haves', 'nice_to_have', 'preferred_skills', 'job_mode',
#        'employment_type', 'non_technical_skills', 'technical_skills',
#        'selection_criteria.resume_shortlist_criteria',
#        'selection_criteria.screening_qualification_criteria',
#        'selection_criteria.final_interview_criteria',
#        'selection_progress.total_candidate_count',
#        'selection_progress.shortlisted_candidate_count',
#        'selection_progress.screening_qualified_count',
#        'selection_progress.final_interview_qualified_count', 'job_type'],
#       dtype='object')
