# %%
pip install pymongo
# Out:
# ...
#   Using cached pymongo-4.13.2-cp312-cp312-win_amd64.whl.metadata (22 kB)
# ...
# Using cached pymongo-4.13.2-cp312-cp312-win_amd64.whl (903 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
pd.set_option("display.max_column", None)
from pymongo import MongoClient

mongo_url = "mongodb://padma:d6g5h1dh18dh1d6h81fd86d1UBFIfguifd@3.146.176.180:27017/talentsync-backend-production"
client = MongoClient(mongo_url)
print("Python-MongoDB connection created succesfully -\n", client)
# Out:
# Python-MongoDB connection created succesfully -
#  MongoClient(host=['3.146.176.180:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
output_dir = "production_data/raw_data_dump"
os.makedirs(output_dir, exist_ok=True)
print("Folder created succesfully")
# Out:
# Folder created succesfully

# %%
db = client['talentsync-backend-production']
collection_names = db.list_collection_names()
print(collection_names)
# Out:
# ['candidate_questions', 'job_hr_questions', 'candidates', 'auth_keys', 'jobs', 'job_hr_settings', 'batches', 'questions', 'candidates_errors', 'users', 'companies', 'messages', 'auth_tokens']

# %%
for coll_name in collection_names:
    collection = db[coll_name]
    documents = list(collection.find({}))
    
    df = pd.json_normalize(documents)
    
    output_path = os.path.join(output_dir, f"{coll_name}.csv")
    df.to_csv(output_path, index=False)
    print(f"Dumped: {output_path}")

print("\nAll collections dumped successfully!")
# Out:
# Dumped: production_data/raw_data_dump\candidate_questions.csv
# Dumped: production_data/raw_data_dump\job_hr_questions.csv
# Dumped: production_data/raw_data_dump\candidates.csv
# Dumped: production_data/raw_data_dump\auth_keys.csv
# Dumped: production_data/raw_data_dump\jobs.csv
# Dumped: production_data/raw_data_dump\job_hr_settings.csv
# Dumped: production_data/raw_data_dump\batches.csv
# Dumped: production_data/raw_data_dump\questions.csv
# Dumped: production_data/raw_data_dump\candidates_errors.csv
# Dumped: production_data/raw_data_dump\users.csv
# Dumped: production_data/raw_data_dump\companies.csv
# Dumped: production_data/raw_data_dump\messages.csv
# Dumped: production_data/raw_data_dump\auth_tokens.csv
#
# All collections dumped successfully!

# %%
# df_auth_keys = pd.read_csv("production_data/raw_data_dump/auth_keys.csv")
# df_auth_keys.head()

# %%
# df_auth_tokens = pd.read_csv("production_data/raw_data_dump/auth_tokens.csv")
# df_auth_tokens.head()

# %%
df_batches = pd.read_csv("production_data/raw_data_dump/batches.csv")
df_batches.head()
# Out:
#                         _id               uploaded_by  \
# 0  6822eb6f6342bdaa117239be  6822e2f56342bdaa117239b8
# 1  6822f3e46342bdaa117239c7  6822e2f56342bdaa117239b8
# 2  6822f5d26342bdaa117239ca  6822e2f56342bdaa117239b8
# 3  6822f6896342bdaa117239cb  6822e2f56342bdaa117239b8
# 4  682361636342bdaa11723a48  6818f9601ec8f4553059c40e
#
#                  company_id  \
# 0  6822e3346342bdaa117239ba
# 1  6822e3346342bdaa117239ba
# 2  6822e3346342bdaa117239ba
# 3  6822e3346342bdaa117239ba
# 4  681c861b1cf44d32fe03095e
#
#                                             batch_id         batch_name  \
# 0           b'm\x18]v\xf2>Rv\x867C\x03\xf9I\xb7\xa8'      Batch - SIS 1
# 1  b'\xc9\xe1\x1e\x13W\x95Ud\x89\x00\xdf\xd2\x01\...          Batch - 2
# 2  b'Wy\xb4\x07\xf3\x0fX.\xa6x\xd2\r\x98\xd5\x1e\...  batch - emily pdf
# 3        b'.\x95\xe2\x8f(W^\xd6\xb7dM\xd3bs\x04\xd2'         batch - hr
# 4      b'u\x9f\xae\x00HTQa\xb0\\\t\xba\x114\xaf\x0b'     resume_product
#
# ...

# %%
df_candidate_questions = pd.read_csv("production_data/raw_data_dump/candidate_questions.csv")
df_candidate_questions.head()
# Out:
#                         _id              candidate_id  \
# 0  6821f0a86342bdaa1172396c  6821f0883d9e6a1581409215
# 1  6821f0a86342bdaa1172396d  6821f0883d9e6a1581409216
# 2  6821f0a86342bdaa1172396e  6821f0883d9e6a1581409217
# 3  6821f0a86342bdaa1172396f  6821f0883d9e6a1581409218
# 4  6821f0a86342bdaa11723970  6821f0883d9e6a1581409219
#
#                                            questions               created_at  \
# 0  ['Given your extensive experience in human res...  2025-05-12 12:58:58.355
# 1  ['Can you describe any experience you have wit...  2025-05-12 12:59:04.359
# 2  ['Given your extensive experience in human res...  2025-05-12 12:59:10.203
# 3  ['Can you describe a project where you had to ...  2025-05-12 12:59:15.161
# 4  ['Can you describe a project where you utilize...  2025-05-12 12:59:20.035
#
#                 updated_at
# 0  2025-05-12 12:58:58.355
# 1  2025-05-12 12:59:04.359
# 2  2025-05-12 12:59:10.203
# 3  2025-05-12 12:59:15.161
# 4  2025-05-12 12:59:20.035

# %%
# df_candidates_errors = pd.read_csv("production_data/raw_data_dump/candidates_errors.csv")
# df_candidates_errors.head(2)

# %%
df_candidates = pd.read_csv("production_data/raw_data_dump/candidates.csv")
df_candidates.head()
# Out:
#                         _id               created_at               updated_at  \
# 0  682207656342bdaa11723988  2025-05-12 14:36:21.192  2025-05-12 14:36:21.192
# 1  682207f36342bdaa11723989  2025-05-12 14:38:43.661  2025-05-12 14:38:43.661
# 2  68220d606342bdaa1172398a  2025-05-12 15:01:52.513  2025-05-12 15:01:52.513
# 3  68220f3b6342bdaa1172398b  2025-05-12 15:09:47.500  2025-05-12 15:09:47.500
# 4  6822125b6342bdaa1172398c  2025-05-12 15:23:07.850  2025-05-12 15:23:07.850
#
#                  company_id                    job_id            name  \
# 0  682200936342bdaa1172397a  6822017e6342bdaa1172397d  Supriya Ricard
# 1  682200936342bdaa1172397a  6822017e6342bdaa1172397d     Sourav Rooj
# 2  682200936342bdaa1172397a  6822017e6342bdaa1172397d  Supriya Patra
# 3  682200936342bdaa1172397a  6822017e6342bdaa1172397d      John Smith
# 4  682200936342bdaa1172397a  6822017e6342bdaa1172397d      Sourav Ruj
#
#                        email  phone_no status     type secondary_email  \
# ...

# %%
df_companies = pd.read_csv("production_data/raw_data_dump/companies.csv")
df_companies.head()
# Out:
#                         _id                                    name  \
# 0  681c861b1cf44d32fe03095e                         Klizo Solutions
# 1  681c86b51cf44d32fe030963  Vietnam Australia International School
# 2  681c872f1cf44d32fe03096d                              Esco Beach
# 3  682200046342bdaa11723975                   Furarma Resort Danang
# 4  682200936342bdaa1172397a                   Furama Resort Da Nang
#
#   organization_size company_type               created_at  \
# 0             11-50  corporation  2025-05-08 10:23:23.615
# 1              200+  corporation  2025-05-08 10:25:57.981
# 2            51-200  corporation  2025-05-08 10:27:59.721
# 3              200+  corporation  2025-05-12 14:04:52.549
# 4              200+  corporation  2025-05-12 14:07:15.794
#
#                 updated_at  is_deleted
# 0  2025-05-08 10:23:23.615       False
# 1  2025-05-08 10:25:57.981       False
# 2  2025-05-08 10:27:59.721       False
# 3  2025-05-12 14:04:52.549       False
# ...

# %%
# df_job_hr_questions = pd.read_csv("production_data/raw_data_dump/job_hr_questions.csv")
# df_job_hr_questions.head()

# %%
# df_job_hr_settings = pd.read_csv("production_data/raw_data_dump/job_hr_settings.csv")
# df_job_hr_settings.head()

# %%
df_jobs = pd.read_csv("production_data/raw_data_dump/jobs.csv")
df_jobs.head(2)
# Out:
#                         _id                   title         job_id  \
# 0  6819085351179958a6041971        AI Sales Manager  JOB-AS-250505
# 1  68190c5c51179958a6041977  Human Resource Manager  JOB-HR-250505
#
#                                                 tags  status  \
# 0                                  ['Sales', 'Saas']  closed
# 1  ['Hr', 'Ai', 'Saas', 'Technology', 'Recruitment']  closed
#
#                 created_at               updated_at  is_deleted  \
# 0  2025-05-05 18:49:48.696  2025-06-12 15:43:48.710       False
# 1  2025-05-05 19:06:56.908  2025-06-12 09:23:57.898       False
#
#                  company_id location  address  \
# 0  681c861b1cf44d32fe03095e  Vietnam  Vietnam
# 1  681c861b1cf44d32fe03095e  Vietnam  Vietnam
#
#                         job_post_name  \
# 0        AI Sales Manager (2–5 Years)
# 1  Human Resource Manager (4–6 Years)
#
#                                     role_description experience  \
# ...

# %%
# df_messages = pd.read_csv("production_data/raw_data_dump/messages.csv")
# df_messages.head()

# %%
df_questions = pd.read_csv("production_data/raw_data_dump/questions.csv")
df_questions.head(2)
# Out:
#                         _id  priority                    job_id  \
# 0  6819089451179958a6041972       1.0  6819085351179958a6041971
# 1  6819089451179958a6041973       2.0  6819085351179958a6041971
#
#                  company_id  \
# 0  681c861b1cf44d32fe03095e
# 1  681c861b1cf44d32fe03095e
#
#                                             question  follow_up_count  \
# 0  Can you describe a project where you successfu...              3.0
# 1  How do you stay updated on AI trends, and can ...              2.0
#
#                 created_at               updated_at  position  \
# 0  2025-05-05 18:51:00.418  2025-05-06 10:17:36.946       1.0
# 1  2025-05-05 18:51:00.418  2025-05-06 10:17:36.946       2.0
#
#   question.question question_type questions
# 0               NaN           NaN       NaN
# 1               NaN           NaN       NaN

# %%
df_users = pd.read_csv("production_data/raw_data_dump/users.csv")
df_users.head()
# Out:
#                         _id  firstname  lastname                 email  \
# 0  6818f8b61ec8f4553059c408  Subhadeep  Banerjee  subhadeep@klizos.com
# 1  6818f9461ec8f4553059c40c     Joseph    Ricard       joey@klizos.com
# 2  6818f9601ec8f4553059c40e    Supriyo    Mondal    smondal@klizos.com
# 3  6818f9811ec8f4553059c410      Henry    Greeff      henry@klizos.com
# 4  6819ea8a51179958a604199d  Nirmallya     Koner  nirmallya@klizos.com
#
#                                             password               created_at  \
# 0  $2b$12$LLaZuBdx5PILWNBn4O4t7OrS58VlQHHW0x69TeF...  2025-05-05 17:43:18.484
# 1  $2b$12$AVyPehV2O5S6mPDcq10DJelhTUERQXHS7T4Wj.i...  2025-05-05 17:45:42.541
# 2  $2b$12$XiU4SC.nLQjTUfCV8VgkEOhIvQhi96p.0EXrjUq...  2025-05-05 17:46:08.148
# 3  $2b$12$nYub1OPtDknzlMTKIIW5k.EwnBqjyGchA.w9Q3i...  2025-05-05 17:46:41.067
# 4  $2b$12$M1d01hGMKvqae1XGOsfpNuJsZ72frQudkP.vx.H...  2025-05-06 10:55:06.592
#
# ...

# %%
req_collections = [
    'candidate_questions', 'candidates', 'jobs', 'questions', 'users', 'companies', 'batches'
]

# %%
df_companies = pd.read_csv("production_data/raw_data_dump/companies.csv")
df_companies.columns
# Out:
# Index(['_id', 'name', 'organization_size', 'company_type', 'created_at',
#        'updated_at', 'is_deleted'],
#       dtype='object')

# %%
df_users = pd.read_csv("production_data/raw_data_dump/users.csv")
df_users.columns
# Out:
# Index(['_id', 'firstname', 'lastname', 'email', 'password', 'created_at',
#        'updated_at', 'phone', 'job_role', 'status', 'role', 'company_id',
#        'social', 'account_state', 'auth_methods', 'google_id', 'social_mode',
#        'profile_pic_url', 'token_usage.gpt-4o-mini.input_token',
#        'token_usage.gpt-4o-mini.output_token', 'deleted', 'expireAt',
#        'linkedin_id'],
#       dtype='object')

# %%
df_jobs = pd.read_csv("production_data/raw_data_dump/jobs.csv")
df_jobs.columns
# Out:
# Index(['_id', 'title', 'job_id', 'tags', 'status', 'created_at', 'updated_at',
#        'is_deleted', 'company_id', 'location', 'address', 'job_post_name',
#        'role_description', 'experience', 'responsibilities', 'requirements',
#        'must_haves', 'nice_to_have', 'preferred_skills', 'job_mode',
#        'employment_type', 'non_technical_skills', 'technical_skills',
#        'selection_criteria.resume_shortlist_criteria',
#        'selection_criteria.screening_qualification_criteria',
#        'selection_criteria.final_interview_criteria',
#        'selection_progress.total_candidate_count',
#        'selection_progress.shortlisted_candidate_count',
#        'selection_progress.screening_qualified_count',
#        'selection_progress.final_interview_qualified_count', 'job_type'],
#       dtype='object')

# %%
df_batches = pd.read_csv("production_data/raw_data_dump/batches.csv")
df_batches.columns
# Out:
# Index(['_id', 'uploaded_by', 'company_id', 'batch_id', 'batch_name',
#        'upload_count', 'job_id', 'status', 'start_time', 'end_time', 'type'],
#       dtype='object')

# %%
df_batches['type'].value_counts()
# Out:
# type
# bulk      49
# single    16
# Name: count, dtype: int64

# %%
df_candidates = pd.read_csv("production_data/raw_data_dump/candidates.csv")
df_candidates.columns
# Out:
# Index(['_id', 'created_at', 'updated_at', 'company_id', 'job_id', 'name',
#        'email', 'phone_no', 'status', 'type', 'secondary_email',
#        'primary_phone', 'secondary_phone', 'cv_directory_link', 'unique_id',
#        'designation', 'location', 'education', 'work_experience',
#        'total_experience', 'technical_skills', 'soft_skills', 'languages',
#        'certifications', 'projects', 'batch_id',
#        'personal_details.date_of_birth', 'personal_details.age',
#        'personal_details.gender', 'social_profiles.github',
#        'social_profiles.linkedin', 'social_profiles.twitter',
#        'social_profiles.leetcode', 'social_profiles.others', 'metadata.pages',
#        'metadata.file_size_kb', 'metadata.file_type', 'metadata.word_count',
#        'metadata.personal_pronoun_count', 'metadata.reading_level',
#        'metadata.vocabulary_level', 'metadata.frequent_words',
#        'compatibility_analysis.overall_score',
# ...

# %%
df_candidate_questions = pd.read_csv("production_data/raw_data_dump/candidate_questions.csv")
df_candidate_questions.columns
# Out:
# Index(['_id', 'candidate_id', 'questions', 'created_at', 'updated_at'], dtype='object')
