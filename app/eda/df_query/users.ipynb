# %% [markdown]
# #### Import required package

# %%
import pandas as pd
pd.set_option("display.max_column", None)

# %% [markdown]
# #### Read the collection data

# %%
df = pd.read_csv("../../../production_data/raw_data_dump/users.csv")
# df.sample(2)
df.head(2)
# Out:
#                         _id  firstname  lastname                 email  \
# 0  6818f8b61ec8f4553059c408  Subhadeep  Banerjee  subhadeep@klizos.com
# 1  6818f9461ec8f4553059c40c     Joseph    Ricard       joey@klizos.com
#
#                                             password               created_at  \
# 0  $2b$12$LLaZuBdx5PILWNBn4O4t7OrS58VlQHHW0x69TeF...  2025-05-05 17:43:18.484
# 1  $2b$12$AVyPehV2O5S6mPDcq10DJelhTUERQXHS7T4Wj.i...  2025-05-05 17:45:42.541
#
#                 updated_at        phone                job_role  status  \
# 0  2025-06-25 12:24:54.222          NaN  Lead Software Engineer  active
# 1  2025-05-29 13:51:08.435  19546040324                     NaN  active
#
#     role                company_id social  account_state  \
# 0  owner  681c861b1cf44d32fe03095e  False    manual_only
# 1  admin  681c861b1cf44d32fe03095e   True  manual_google
#
#            auth_methods social_mode  \
# 0            ['manual']         NaN
# 1  ['manual', 'google']      google
#
# ...

# %% [markdown]
# #### Inspect the shape and columns of the collection

# %%
print("shape: ", df.shape)
print("Columns: ", df.columns)
# Out:
# shape:  (310, 24)
# Columns:  Index(['_id', 'firstname', 'lastname', 'email', 'password', 'created_at',
#        'updated_at', 'phone', 'job_role', 'status', 'role', 'company_id',
#        'social', 'account_state', 'auth_methods', 'social_mode',
#        'profile_pic_url', 'token_usage.gpt-4o-mini.input_token',
#        'token_usage.gpt-4o-mini.output_token', 'google_id', 'deleted',
#        'expireAt', 'linkedin_id', 'userExpireAt'],
#       dtype='object')

# %% [markdown]
# #### Get a detail info about the docs present in the collection

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 24 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   _id                                   310 non-null    object
#  1   firstname                             98 non-null     object
#  2   lastname                              97 non-null     object
#  3   email                                 98 non-null     object
#  4   password                              82 non-null     object
#  5   created_at                            98 non-null     object
#  6   updated_at                            98 non-null     object
#  7   phone                                 21 non-null     object
#  8   job_role                              41 non-null     object
#  9   status                                98 non-null     object
#  10  role                                  98 non-null     object
# ...

# %% [markdown]
# #### Filter the required Fields

# %%
df_extracted = df[['firstname', 'lastname', 'email', 'created_at', 'updated_at', 'phone', 'job_role', 'status', 'role', 'social', 'account_state', 'auth_methods', 'social_mode']]
df_extracted.head()
# Out:
#    firstname  lastname                 email               created_at  \
# 0  Subhadeep  Banerjee  subhadeep@klizos.com  2025-05-05 17:43:18.484
# 1     Joseph    Ricard       joey@klizos.com  2025-05-05 17:45:42.541
# 2    Supriyo    Mondal    smondal@klizos.com  2025-05-05 17:46:08.148
# 3      Henry    Greeff      henry@klizos.com  2025-05-05 17:46:41.067
# 4  Nirmallya     Koner  nirmallya@klizos.com  2025-05-06 10:55:06.592
#
#                 updated_at        phone                job_role    status  \
# 0  2025-06-25 12:24:54.222          NaN  Lead Software Engineer    active
# 1  2025-05-29 13:51:08.435  19546040324                     NaN    active
# 2  2025-06-24 14:08:52.267   78945 6123                     NaN    active
# 3  2025-05-28 04:23:41.658          NaN                     NaN    active
# 4  2025-06-12 16:07:15.458          NaN                     NaN  inactive
#
#     role social  account_state          auth_methods social_mode
# ...

# %% [markdown]
# #### Count the values of the fields

# %%
df_extracted['status'].value_counts()
# Out:
# status
# active    70
# Name: count, dtype: int64

# %%
df_extracted['auth_methods'].value_counts()
# Out:
# auth_methods
# ['manual']              85
# ['manual', 'google']    10
# ['google']               2
# ['linkedin']             1
# Name: count, dtype: int64

# %%
df_extracted['social_mode'].value_counts()
# Out:
# social_mode
# google      12
# linkedin     1
# Name: count, dtype: int64

# %% [markdown]
# #### Filter the data of users based on 'status'

# %%
df_extracted[df_extracted['status'] == 'active'].head()
# Out:
#    firstname  lastname                 email               created_at  \
# 0  Subhadeep  Banerjee  subhadeep@klizos.com  2025-05-05 17:43:18.484
# 1     Joseph    Ricard       joey@klizos.com  2025-05-05 17:45:42.541
# 2    Supriyo    Mondal    smondal@klizos.com  2025-05-05 17:46:08.148
# 3      Henry    Greeff      henry@klizos.com  2025-05-05 17:46:41.067
# 6       Joey    Ricard  joeyricard@gmail.com  2025-05-06 16:06:35.900
#
#                 updated_at        phone                job_role  status  \
# 0  2025-06-25 12:24:54.222          NaN  Lead Software Engineer  active
# 1  2025-05-29 13:51:08.435  19546040324                     NaN  active
# 2  2025-06-24 14:08:52.267   78945 6123                     NaN  active
# 3  2025-05-28 04:23:41.658          NaN                     NaN  active
# 6  2025-05-06 16:06:57.070          NaN         Human Resources  active
#
#     role social  account_state          auth_methods social_mode email_domain
# ...

# %% [markdown]
# #### Filter the data based on 'role'

# %%
df_extracted[df_extracted['role']=='admin'].head()
# Out:
#    firstname          lastname                     email  \
# 1     Joseph            Ricard           joey@klizos.com
# 3      Henry            Greeff          henry@klizos.com
# 4  Nirmallya             Koner      nirmallya@klizos.com
# 5      Soura              Rooj    sourav.rooj@klizos.com
# 8       User  Klizo soulutions  sourav.rooj+1@klizos.com
#
#                 created_at               updated_at        phone job_role  \
# 1  2025-05-05 17:45:42.541  2025-05-29 13:51:08.435  19546040324      NaN
# 3  2025-05-05 17:46:41.067  2025-05-28 04:23:41.658          NaN      NaN
# 4  2025-05-06 10:55:06.592  2025-06-12 16:07:15.458          NaN      NaN
# 5  2025-05-06 10:55:49.827  2025-06-12 16:07:03.601          NaN      NaN
# 8  2025-05-08 10:22:35.276  2025-05-30 13:56:29.925          NaN   tester
#
#      status   role social  account_state          auth_methods social_mode
# 1    active  admin   True  manual_google  ['manual', 'google']      google
# ...

# %% [markdown]
# #### Filter the data based on 'social_mode'

# %%
df_extracted[df_extracted['social_mode']=='linkedin']
# Out:
#    firstname lastname              email               created_at  \
# 74     Kumar    Rahul  piyali@klizos.com  2025-06-10 09:21:50.577
#
#                  updated_at phone job_role  status   role social  \
# 74  2025-06-10 09:21:50.577   NaN  Analyst  active  owner   True
#
#     account_state  auth_methods social_mode
# 74  linkedin_only  ['linkedin']    linkedin

# %%
df[df['social_mode']=='linkedin']
# Out:
#                          _id firstname lastname              email password  \
# 74  6847f92eeabd1dae68df0871     Kumar    Rahul  piyali@klizos.com      NaN
#
#                  created_at               updated_at phone job_role  status  \
# 74  2025-06-10 09:21:50.577  2025-06-10 09:21:50.577   NaN  Analyst  active
#
#      role                company_id social  account_state  auth_methods  \
# 74  owner  6847f945eabd1dae68df0873   True  linkedin_only  ['linkedin']
#
#    social_mode                                    profile_pic_url  \
# 74    linkedin  https://media.licdn.com/dms/image/v2/D4E03AQFa...
#
#     token_usage.gpt-4o-mini.input_token  token_usage.gpt-4o-mini.output_token  \
# 74                                  NaN                                   NaN
#
#    google_id deleted expireAt linkedin_id userExpireAt
# 74       NaN     NaN      NaN  FHf_9kLxDU          NaN

# %% [markdown]
# #### Filter the data with multiple filter criteria

# %%
df_extracted[
    (df_extracted['role']=='admin') & 
    (df_extracted['email'].str.endswith('@klizos.com')) & 
    (df_extracted['job_role'] != 'tester') & 
    (df_extracted['status']=='active')
].head()
# Out:
#    firstname lastname                  email               created_at  \
# 1     Joseph   Ricard        joey@klizos.com  2025-05-05 17:45:42.541
# 3      Henry   Greeff       henry@klizos.com  2025-05-05 17:46:41.067
# 11     Henry   Greeff  henry+esco@klizos.com  2025-05-08 12:32:12.897
# 13   Supriya    Patra     supriya@klizos.com  2025-05-08 13:09:55.234
# 18   Supriya    Patra   supriya+1@klizos.com  2025-05-12 14:31:07.651
#
#                  updated_at         phone job_role  status   role social  \
# 1   2025-05-29 13:51:08.435   19546040324      NaN  active  admin   True
# 3   2025-05-28 04:23:41.658           NaN      NaN  active  admin   True
# 11  2025-05-08 13:03:20.702  840985715670      NaN  active  admin  False
# 13  2025-06-17 12:32:05.133  919748818605      NaN  active  admin   True
# 18  2025-05-12 14:33:44.275           NaN      NaN  active  admin  False
#
#     account_state          auth_methods social_mode
# 1   manual_google  ['manual', 'google']      google
# ...

# %%
df_extracted['email_domain'] = df_extracted['email'].str.extract(r'@([\w\.-]+)$')

domain_counts = df_extracted['email_domain'].value_counts()

print(domain_counts)

# %%
df_extracted['email'].str.extract(r'@([\w\.-]+)$').value_counts()
# Out:
# 0
# klizos.com       89
# gmail.com         5
# mydevguys.com     3
# gmail.vom         1
# Name: count, dtype: int64

# %%
df_extracted['email_domain'] = df_extracted['email'].str.extract(r'@([\w\.-]+)$')
df_extracted.head()
# Out:
# C:\Users\Padma Dey\AppData\Local\Temp\ipykernel_9580\3607789020.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_extracted['email_domain'] = df_extracted['email'].str.extract(r'@([\w\.-]+)$')
#    firstname  lastname                 email               created_at  \
# 0  Subhadeep  Banerjee  subhadeep@klizos.com  2025-05-05 17:43:18.484
# 1     Joseph    Ricard       joey@klizos.com  2025-05-05 17:45:42.541
# 2    Supriyo    Mondal    smondal@klizos.com  2025-05-05 17:46:08.148
# 3      Henry    Greeff      henry@klizos.com  2025-05-05 17:46:41.067
# 4  Nirmallya     Koner  nirmallya@klizos.com  2025-05-06 10:55:06.592
#
#                 updated_at        phone                job_role    status  \
# ...

# %%
df_extracted[df_extracted['email_domain'] != 'gmail.vom'].head()
# Out:
#    firstname  lastname                 email               created_at  \
# 0  Subhadeep  Banerjee  subhadeep@klizos.com  2025-05-05 17:43:18.484
# 1     Joseph    Ricard       joey@klizos.com  2025-05-05 17:45:42.541
# 2    Supriyo    Mondal    smondal@klizos.com  2025-05-05 17:46:08.148
# 3      Henry    Greeff      henry@klizos.com  2025-05-05 17:46:41.067
# 4  Nirmallya     Koner  nirmallya@klizos.com  2025-05-06 10:55:06.592
#
#                 updated_at        phone                job_role    status  \
# 0  2025-06-25 12:24:54.222          NaN  Lead Software Engineer    active
# 1  2025-05-29 13:51:08.435  19546040324                     NaN    active
# 2  2025-06-24 14:08:52.267   78945 6123                     NaN    active
# 3  2025-05-28 04:23:41.658          NaN                     NaN    active
# 4  2025-06-12 16:07:15.458          NaN                     NaN  inactive
#
#     role social  account_state          auth_methods social_mode email_domain
# ...

# %%
df_extracted[['auth_methods']].value_counts()
# Out:
# auth_methods
# ['manual']              85
# ['manual', 'google']    10
# ['google']               2
# ['linkedin']             1
# Name: count, dtype: int64

# %%
df_extracted['auth_methods'].apply(type).value_counts()
# Out:
# auth_methods
# <class 'float'>    212
# <class 'str'>       98
# Name: count, dtype: int64

# %%
import ast

df_extracted['auth_methods_count'] = df_extracted['auth_methods'].apply(
    lambda x: len(ast.literal_eval(x)) if isinstance(x, str) else (len(x) if isinstance(x, list) else 0)
)


df_extracted[['auth_methods','auth_methods_count']].head()
# Out:
# C:\Users\Padma Dey\AppData\Local\Temp\ipykernel_9580\1457958854.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_extracted['auth_methods_count'] = df_extracted['auth_methods'].apply(
#            auth_methods  auth_methods_count
# 0            ['manual']                   1
# 1  ['manual', 'google']                   2
# 2  ['manual', 'google']                   2
# 3  ['manual', 'google']                   2
# 4            ['manual']                   1

# %%
df_extracted[df_extracted['auth_methods_count'] > 1]
# Out:
#     firstname   lastname                   email               created_at  \
# 1      Joseph     Ricard         joey@klizos.com  2025-05-05 17:45:42.541
# 2     Supriyo     Mondal      smondal@klizos.com  2025-05-05 17:46:08.148
# 3       Henry     Greeff        henry@klizos.com  2025-05-05 17:46:41.067
# 13    Supriya      Patra      supriya@klizos.com  2025-05-08 13:09:55.234
# 27      Rahul      Kumar      rahul.k@klizos.com  2025-05-14 10:50:17.093
# 36   Mohammad     Danish       danish@klizos.com  2025-05-26 12:40:02.908
# 47   Nabanita   Banerjee     nabanita@klizos.com  2025-05-30 13:57:26.272
# 93     Kuheli        Das       kuheli@klizos.com  2025-06-13 09:34:19.865
# 95   Anshuman     Mandal     a.mandal@klizos.com  2025-06-13 09:36:41.852
# 108   sourabh  kumar das  sourabh.das@klizos.com  2025-06-17 09:37:02.588
#
#                   updated_at         phone   job_role  status   role social  \
# 1    2025-05-29 13:51:08.435   19546040324        NaN  active  admin   True
# ...

# %%
df_extracted[df_extracted['email_domain'] == 'gmail.vom'].head()
# Out:
#    firstname    lastname                      email               created_at  \
# 55    jvACBu  WBFVWHFGUF  q29ryq98yrq8ryq@gmail.vom  2025-06-03 12:49:32.683
#
#                  updated_at        phone job_role status    role social  \
# 55  2025-06-03 12:49:32.683  18289388290      NaN    new  viewer  False
#
#    account_state auth_methods social_mode email_domain
# 55   manual_only   ['manual']         NaN    gmail.vom

# %%
df_extracted.columns
# Out:
# Index(['firstname', 'lastname', 'email', 'created_at', 'updated_at', 'phone',
#        'job_role', 'status', 'role', 'social', 'account_state', 'auth_methods',
#        'social_mode', 'email_domain', 'auth_methods_count'],
#       dtype='object')

# %%
df_final = df_extracted[['firstname', 'lastname', 'email', 'phone',
       'job_role', 'status', 'role','account_state', 'auth_methods',
       'email_domain', 'auth_methods_count']]
df_final.head()
# Out:
#    firstname  lastname                 email        phone  \
# 0  Subhadeep  Banerjee  subhadeep@klizos.com          NaN
# 1     Joseph    Ricard       joey@klizos.com  19546040324
# 2    Supriyo    Mondal    smondal@klizos.com   78945 6123
# 3      Henry    Greeff      henry@klizos.com          NaN
# 4  Nirmallya     Koner  nirmallya@klizos.com          NaN
#
#                  job_role    status   role  account_state  \
# 0  Lead Software Engineer    active  owner    manual_only
# 1                     NaN    active  admin  manual_google
# 2                     NaN    active  owner  manual_google
# 3                     NaN    active  admin  manual_google
# 4                     NaN  inactive  admin    manual_only
#
#            auth_methods email_domain  auth_methods_count
# 0            ['manual']   klizos.com                   1
# 1  ['manual', 'google']   klizos.com                   2
# 2  ['manual', 'google']   klizos.com                   2
# ...

# %%
str_cols = df_final.select_dtypes(include=['object', 'string']).columns
str_cols
# Out:
# Index(['firstname', 'lastname', 'email', 'phone', 'job_role', 'status', 'role',
#        'account_state', 'auth_methods', 'email_domain'],
#       dtype='object')

# %%
df_final[str_cols] = df_final[str_cols].fillna("Not Mentioned")
df_final.head()
# Out:
# C:\Users\Padma Dey\AppData\Local\Temp\ipykernel_9580\3282136066.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[str_cols] = df_final[str_cols].fillna("Not Mentioned")
#    firstname  lastname                 email          phone  \
# 0  Subhadeep  Banerjee  subhadeep@klizos.com  Not Mentioned
# 1     Joseph    Ricard       joey@klizos.com    19546040324
# 2    Supriyo    Mondal    smondal@klizos.com     78945 6123
# 3      Henry    Greeff      henry@klizos.com  Not Mentioned
# 4  Nirmallya     Koner  nirmallya@klizos.com  Not Mentioned
#
#                  job_role    status   role  account_state  \
# 0  Lead Software Engineer    active  owner    manual_only
# 1           Not Mentioned    active  admin  manual_google
# ...

# %%
select * 
from df_extracted
where 'role' = 'admin' and 'email' like '%@klizos.com'
