# %% [markdown]
# #### Import required package

# %%
import pandas as pd
pd.set_option("display.max_column", None)

# %% [markdown]
# #### Read the collection data

# %%
df = pd.read_csv("../../../production_data/raw_data_dump/candidates.csv")
df.sample(2)
# Out:
#                           _id               created_at  \
# 76   6822f74d3d9e6a1581409256  2025-05-13 07:37:25.238
# 884  685ade9c3cd3e170c81f4355  2025-06-24 17:21:32.710
#
#                   updated_at                company_id  \
# 76   2025-05-13 07:41:45.597  6822e3346342bdaa117239ba
# 884  2025-06-24 17:30:13.785  681c861b1cf44d32fe03095e
#
#                        job_id                        name  \
# 76   6822eaf56342bdaa117239bd                 Van Nhu Hao
# 884  685921ddc939b52e8b71ae2d  Deborah E. Gonzalez Roncal
#
#                         email  phone_no       status     type  \
# 76    vnhuhao.dn201@gmail.com       NaN          New      NaN
# 884  deborah.roncal@gmail.com       NaN  Shortlisted  general
#
#      progress.round_2.score progress.round_2.value secondary_email  \
# 76                      NaN                    NaN             NaN
# 884                    85.0                   True             NaN
#
#           primary_phone secondary_phone  \
# ...

# %% [markdown]
# #### Inspect the shape and columns of the collection

# %%
print("shape: ", df.shape)
print("Columns: ", df.columns)
# Out:
# shape:  (983, 79)
# Columns:  Index(['_id', 'created_at', 'updated_at', 'company_id', 'job_id', 'name',
#        'email', 'phone_no', 'status', 'type', 'progress.round_2.score',
#        'progress.round_2.value', 'secondary_email', 'primary_phone',
#        'secondary_phone', 'cv_directory_link', 'unique_id', 'designation',
#        'location', 'education', 'work_experience', 'total_experience',
#        'technical_skills', 'soft_skills', 'languages', 'certifications',
#        'projects', 'batch_id', 'total_experience_months',
#        'personal_details.date_of_birth', 'personal_details.age',
#        'personal_details.gender', 'social_profiles.github',
#        'social_profiles.linkedin', 'social_profiles.twitter',
#        'social_profiles.leetcode', 'social_profiles.others', 'metadata.pages',
#        'metadata.file_size_kb', 'metadata.file_type', 'metadata.word_count',
#        'metadata.personal_pronoun_count', 'metadata.reading_level',
# ...

# %% [markdown]
# #### Inspect the detail info of the documents present in the collection

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 983 entries, 0 to 982
# Data columns (total 79 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   _id                                                           983 non-null    object
#  1   created_at                                                    983 non-null    object
#  2   updated_at                                                    983 non-null    object
#  3   company_id                                                    983 non-null    object
#  4   job_id                                                        983 non-null    object
#  5   name                                                          981 non-null    object
#  6   email                                                         983 non-null    object
# ...

# %%
df_klz = df[df['company_id'] == "681c861b1cf44d32fe03095e"]
df_klz.sample(2)
# Out:
#                           _id               created_at  \
# 807  685146c76f49c875e3fa0539  2025-06-17 10:43:10.779
# 181  6826e7d71b85c2b6f71a5c07  2025-05-16 07:23:03.184
#
#                   updated_at                company_id  \
# 807  2025-06-17 10:43:23.960  681c861b1cf44d32fe03095e
# 181  2025-05-16 07:23:03.184  681c861b1cf44d32fe03095e
#
#                        job_id          name                      email  \
# 807  6849372ceabd1dae68df08ad  Chandan Sahu  chandansahuands@gmail.com
# 181  68249d021b85c2b6f71a5bb4   Rahul Kumar      rahul.k+qa@klizos.com
#
#      phone_no       status     type  progress.round_2.score  \
# 807       NaN  Shortlisted      NaN                     NaN
# 181       NaN          new  general                    45.0
#
#     progress.round_2.value secondary_email   primary_phone secondary_phone  \
# 807                    NaN             NaN  +91 8382832152             NaN
# ...
