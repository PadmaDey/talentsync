# %%
import pandas as pd
pd.set_option("display.max_column", None)

# %%
df = pd.read_csv("../../production_data/raw_data_dump/candidates.csv")
df.sample(2)
# Out:
#                           _id               created_at  \
# 222  682d6667d3f3678d7835b740  2025-05-21 05:36:39.434
# 779  684c0a7a6f49c875e3fa0511  2025-06-13 11:24:42.059
#
#                   updated_at                company_id  \
# 222  2025-05-21 05:36:39.434  681c861b1cf44d32fe03095e
# 779  2025-06-13 11:43:16.920  684c0926c939b52e8b71abe7
#
#                        job_id         name                   email  phone_no  \
# 222  682c9800d3f3678d7835b718    ANAS ALAM   anasalam204@gmail.com       NaN
# 779  684c09aec939b52e8b71abeb  Sourav Rooj  sourav.rooj@klizos.com       NaN
#
#           status     type secondary_email primary_phone secondary_phone  \
# 222          new  general             NaN           NaN             NaN
# 779  Shortlisted  general             NaN           NaN             NaN
#
#                             cv_directory_link  \
# 222                                       NaN
# 779  CVs/191f7d22-e96e-5908-8be6-8777153013f2
#
#                                 unique_id           designation  \
# 222                                   NaN                   NaN
# 779  191f7d22-e96e-5908-8be6-8777153013f2  Full Stack Developer
#
#            location                                          education  \
# 222             NaN                                                NaN
# 779  Kolkata, India  [{'degree': "Bachelor's in Computer Science", ...
#
#                                        work_experience  total_experience  \
# 222                                                NaN               NaN
# 779  [{'company_name': 'Klizos', 'position': 'Full ...  2 years 0 months
#
#                                       technical_skills  \
# 222                                                NaN
# 779  ['JavaScript (ES6+)', 'TypeScript', 'React.js'...
#
#                                            soft_skills languages  \
# 222                                                NaN       NaN
# 779  ['Strong communication', 'Team collaboration',...        []
#
#     certifications projects  \
# 222            NaN      NaN
# 779             []       []
#
#                                               batch_id  \
# 222                                                NaN
# 779  b"\xcb4^\xf4\xfe\x95^\xef\xad\xa4\x9e\x05o\x9a'7"
#
#     personal_details.date_of_birth  personal_details.age  \
# 222                            NaN                   NaN
# 779                            NaN                   0.0
#
#     personal_details.gender social_profiles.github social_profiles.linkedin  \
# 222                     NaN                    NaN                      NaN
# 779                     NaN                    NaN                      NaN
#
#     social_profiles.twitter social_profiles.leetcode social_profiles.others  \
# 222                     NaN                      NaN                    NaN
# 779                     NaN                      NaN                     []
#
#      metadata.pages  metadata.file_size_kb metadata.file_type  \
# 222             NaN                    NaN                NaN
# 779             2.0              2272256.0                PDF
#
#      metadata.word_count  metadata.personal_pronoun_count  \
# 222                  NaN                              NaN
# 779                173.0                              0.0
#
#      metadata.reading_level  metadata.vocabulary_level  \
# 222                     NaN                        NaN
# 779                    17.8                       7.05
#
#                                metadata.frequent_words  \
# 222                                                NaN
# 779  ['-', 'and', 'with', 'full', 'stack', 'in', 'd...
#
#      compatibility_analysis.overall_score  \
# 222                                   NaN
# 779                                  72.5
#
#              compatibility_analysis.analysis.strengths  \
# 222                                                NaN
# 779  ['Proficient in TypeScript and Node.js', 'Expe...
#
#                   compatibility_analysis.analysis.gaps  \
# 222                                                NaN
# 779  ['Only 2 years of backend development experien...
#
#        compatibility_analysis.analysis.matching_points  \
# 222                                                NaN
# 779  ['Strong knowledge of Git and version control ...
#
#      compatibility_analysis.analysis.improvement_areas  \
# 222                                                NaN
# 779  ['Gain more backend development experience to ...
#
#      compatibility_analysis.detailed_scoring.skills_match  \
# 222                                                NaN
# 779                                               75.0
#
#      compatibility_analysis.detailed_scoring.experience_relevance  \
# 222                                                NaN
# 779                                               50.0
#
#      compatibility_analysis.detailed_scoring.education_fit  \
# 222                                                NaN
# 779                                               80.0
#
#      compatibility_analysis.detailed_scoring.overall_potential  \
# 222                                                NaN
# 779                                               70.0
#
#      ats_analysis.ats_score  \
# 222                     NaN
# 779                    75.0
#
#     ats_analysis.skills_summary.measurable_achievements  \
# 222                                                NaN
# 779                                                 []
#
#                ats_analysis.skills_summary.hard_skills  \
# 222                                                NaN
# 779  ['JavaScript (ES6+)', 'TypeScript', 'React.js'...
#
#                ats_analysis.skills_summary.soft_skills  \
# 222                                                NaN
# 779  ['Strong communication', 'Team collaboration',...
#
#      ats_analysis.skills_summary.skills_efficiency_score  \
# 222                                                NaN
# 779                                              20.69
#
#                                 ats_analysis.red_flags  \
# 222                                                NaN
# 779  ['No measurable achievements listed to demonst...
#
#                           ats_analysis.recommendations progress.round_1  \
# 222                                                NaN              NaN
# 779  ['Add measurable achievements or specific proj...             True
#
#     progress.round_2
# 222              NaN
# 779            False

# %%
print("shape: ", df.shape)
print("Columns: ", df.columns)
# Out:
# shape:  (846, 60)
# Columns:  Index(['_id', 'created_at', 'updated_at', 'company_id', 'job_id', 'name',
#        'email', 'phone_no', 'status', 'type', 'secondary_email',
#        'primary_phone', 'secondary_phone', 'cv_directory_link', 'unique_id',
#        'designation', 'location', 'education', 'work_experience',
#        'total_experience', 'technical_skills', 'soft_skills', 'languages',
#        'certifications', 'projects', 'batch_id',
#        'personal_details.date_of_birth', 'personal_details.age',
#        'personal_details.gender', 'social_profiles.github',
#        'social_profiles.linkedin', 'social_profiles.twitter',
#        'social_profiles.leetcode', 'social_profiles.others', 'metadata.pages',
#        'metadata.file_size_kb', 'metadata.file_type', 'metadata.word_count',
#        'metadata.personal_pronoun_count', 'metadata.reading_level',
#        'metadata.vocabulary_level', 'metadata.frequent_words',
#        'compatibility_analysis.overall_score',
#        'compatibility_analysis.analysis.strengths',
#        'compatibility_analysis.analysis.gaps',
#        'compatibility_analysis.analysis.matching_points',
#        'compatibility_analysis.analysis.improvement_areas',
#        'compatibility_analysis.detailed_scoring.skills_match',
#        'compatibility_analysis.detailed_scoring.experience_relevance',
#        'compatibility_analysis.detailed_scoring.education_fit',
#        'compatibility_analysis.detailed_scoring.overall_potential',
#        'ats_analysis.ats_score',
#        'ats_analysis.skills_summary.measurable_achievements',
#        'ats_analysis.skills_summary.hard_skills',
#        'ats_analysis.skills_summary.soft_skills',
#        'ats_analysis.skills_summary.skills_efficiency_score',
#        'ats_analysis.red_flags', 'ats_analysis.recommendations',
#        'progress.round_1', 'progress.round_2'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 846 entries, 0 to 845
# Data columns (total 60 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   _id                                                           846 non-null    object
#  1   created_at                                                    846 non-null    object
#  2   updated_at                                                    846 non-null    object
#  3   company_id                                                    846 non-null    object
#  4   job_id                                                        846 non-null    object
#  5   name                                                          846 non-null    object
#  6   email                                                         846 non-null    object
#  7   phone_no                                                      0 non-null      float64
#  8   status                                                        846 non-null    object
#  9   type                                                          403 non-null    object
#  10  secondary_email                                               5 non-null      object
#  11  primary_phone                                                 450 non-null    object
#  12  secondary_phone                                               20 non-null     object
#  13  cv_directory_link                                             471 non-null    object
#  14  unique_id                                                     471 non-null    object
#  15  designation                                                   377 non-null    object
#  16  location                                                      388 non-null    object
#  17  education                                                     471 non-null    object
#  18  work_experience                                               471 non-null    object
#  19  total_experience                                              471 non-null    object
#  20  technical_skills                                              471 non-null    object
#  21  soft_skills                                                   471 non-null    object
#  22  languages                                                     471 non-null    object
#  23  certifications                                                471 non-null    object
#  24  projects                                                      471 non-null    object
#  25  batch_id                                                      471 non-null    object
#  26  personal_details.date_of_birth                                131 non-null    object
#  27  personal_details.age                                          471 non-null    float64
#  28  personal_details.gender                                       47 non-null     object
#  29  social_profiles.github                                        31 non-null     object
#  30  social_profiles.linkedin                                      179 non-null    object
#  31  social_profiles.twitter                                       5 non-null      object
#  32  social_profiles.leetcode                                      2 non-null      object
#  33  social_profiles.others                                        471 non-null    object
#  34  metadata.pages                                                471 non-null    float64
#  35  metadata.file_size_kb                                         471 non-null    float64
#  36  metadata.file_type                                            471 non-null    object
#  37  metadata.word_count                                           471 non-null    float64
#  38  metadata.personal_pronoun_count                               471 non-null    float64
#  39  metadata.reading_level                                        471 non-null    float64
#  40  metadata.vocabulary_level                                     471 non-null    float64
#  41  metadata.frequent_words                                       471 non-null    object
#  42  compatibility_analysis.overall_score                          471 non-null    float64
#  43  compatibility_analysis.analysis.strengths                     471 non-null    object
#  44  compatibility_analysis.analysis.gaps                          471 non-null    object
#  45  compatibility_analysis.analysis.matching_points               471 non-null    object
#  46  compatibility_analysis.analysis.improvement_areas             471 non-null    object
#  47  compatibility_analysis.detailed_scoring.skills_match          471 non-null    float64
#  48  compatibility_analysis.detailed_scoring.experience_relevance  471 non-null    float64
#  49  compatibility_analysis.detailed_scoring.education_fit         471 non-null    float64
#  50  compatibility_analysis.detailed_scoring.overall_potential     471 non-null    float64
#  51  ats_analysis.ats_score                                        471 non-null    float64
#  52  ats_analysis.skills_summary.measurable_achievements           471 non-null    object
#  53  ats_analysis.skills_summary.hard_skills                       471 non-null    object
#  54  ats_analysis.skills_summary.soft_skills                       471 non-null    object
#  55  ats_analysis.skills_summary.skills_efficiency_score           471 non-null    float64
#  56  ats_analysis.red_flags                                        471 non-null    object
#  57  ats_analysis.recommendations                                  471 non-null    object
#  58  progress.round_1                                              470 non-null    object
#  59  progress.round_2                                              92 non-null     object
# dtypes: float64(15), object(45)
# memory usage: 396.7+ KB
