# %%
import pandas as pd
pd.set_option("display.max_column", None)

# %%
df = pd.read_csv("../../production_data/raw_data_dump/jobs.csv")
df.sample(2)
# Out:
#                          _id                                    title  \
# 22  68306b2d0582447f62edadcd  Commercial Real Estate Property Manager
# 31  683568aede4f05c873948b00              Laravel Developer (Fresher)
#
#            job_id                                               tags  status  \
# 22  JOB-CR-250523                    ['Manager', 'Property Manager']  closed
# 31  JOB-LD-250527  ['Laravel, Php, Fresher Job, Web Development, ...  closed
#
#                  created_at               updated_at  is_deleted  \
# 22  2025-05-23 12:33:39.857  2025-06-10 13:27:30.289       False
# 31  2025-05-27 07:24:23.204  2025-06-12 09:20:40.744       False
#
#                   company_id                      location  \
# 22  681c861b1cf44d32fe03095e                 United States
# 31  681c861b1cf44d32fe03095e  Not specified, Not specified
#
#                                               address  \
# 22  United States (Remote/On-Site, Based on Proper...
# 31                                      Not specified
#
#                                         job_post_name  \
# 22  Commercial Real Estate Property Manager (Mid t...
# 31                        Laravel Developer (Fresher)
#
#                                      role_description experience  \
# 22  We are seeking a highly organized and proactiv...   3+ years
# 31  We are hiring freshers who want to start their...    Fresher
#
#                                      responsibilities  \
# 22  ['Manage all aspects of assigned commercial re...
# 31  ['Help build websites and web apps using Larav...
#
#                                          requirements  \
# 22  ['Bachelor’s degree in Real Estate, Business A...
# 31  ['Basic knowledge of PHP and Laravel.', 'Basic...
#
#                                            must_haves  \
# 22  ['Bachelor’s degree in Real Estate, Business A...
# 31            ['Basic knowledge of PHP and Laravel.']
#
#                                          nice_to_have preferred_skills  \
# 22  ['CPM or RPA certification.', 'Proven ability ...              NaN
# 31  ['You’ve built any small project using Laravel...              NaN
#
#    job_mode employment_type  \
# 22   Hybrid       Full-time
# 31   Remote       Full-time
#
#                                  non_technical_skills  \
# 22  ['Communication', 'Negotiation', 'Conflict Res...
# 31               ['Communication', 'Problem Solving']
#
#                                      technical_skills  \
# 22                       ['Yardi', 'MRI', 'AppFolio']
# 31  ['PHP', 'Laravel', 'MySQL', 'HTML', 'CSS', 'Ja...
#
#     selection_criteria.resume_shortlist_criteria  \
# 22                                          60.0
# 31                                          60.0
#
#     selection_criteria.screening_qualification_criteria  \
# 22                                               60.0
# 31                                               60.0
#
#     selection_criteria.final_interview_criteria  \
# 22                                         60.0
# 31                                         60.0
#
#     selection_progress.total_candidate_count  \
# 22                                       0.0
# 31                                       4.0
#
#     selection_progress.shortlisted_candidate_count  \
# 22                                             0.0
# 31                                             0.0
#
#     selection_progress.screening_qualified_count  \
# 22                                           0.0
# 31                                           0.0
#
#     selection_progress.final_interview_qualified_count       job_type
# 22                                                0.0   non-technical
# 31                                                0.0       technical

# %%
print("shape: ", df.shape)
print("Columns: ", df.columns)
# Out:
# shape:  (90, 31)
# Columns:  Index(['_id', 'title', 'job_id', 'tags', 'status', 'created_at', 'updated_at',
#        'is_deleted', 'company_id', 'location', 'address', 'job_post_name',
#        'role_description', 'experience', 'responsibilities', 'requirements',
#        'must_haves', 'nice_to_have', 'preferred_skills', 'job_mode',
#        'employment_type', 'non_technical_skills', 'technical_skills',
#        'selection_criteria.resume_shortlist_criteria',
#        'selection_criteria.screening_qualification_criteria',
#        'selection_criteria.final_interview_criteria',
#        'selection_progress.total_candidate_count',
#        'selection_progress.shortlisted_candidate_count',
#        'selection_progress.screening_qualified_count',
#        'selection_progress.final_interview_qualified_count', 'job_type'],
#       dtype='object')

# %%
df.info()
